# %% [markdown]
# <a href="https://colab.research.google.com/github/guihunwansui/hello-world/blob/main/kpam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/weigao95/mankey-ros
# Out:
# Cloning into 'mankey-ros'...
# remote: Enumerating objects: 100, done.
# remote: Total 100 (delta 0), reused 0 (delta 0), pack-reused 100 (from 1)
# Receiving objects: 100% (100/100), 786.77 KiB | 14.57 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !git clone https://github.com/RobotLocomotion/manip_dataset
#!python3 manip_dataset/data_downloader.py --config_file "config/kpam_mugs.yaml"
# Out:
# Cloning into 'manip_dataset'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 47 (delta 18), reused 29 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (47/47), 12.04 KiB | 12.04 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
# !python3 manip_dataset/data_downloader.py --config_file "config/kpam_mugs.yaml"
# Out:
# ----- Processing episode 2018-05-09-17-32-07 ---------
# ...
# downloading from url: http://data.csail.mit.edu/rlg_manipulation/pdccompressed/logs_proto/2018-05-09-17-32-07.tar.gz
# ...
# Extracting episode to /content/manip_dataset/data
#
#
# ----- Processing episode 2018-05-09-17-34-32 ---------
# ...
# downloading from url: http://data.csail.mit.edu/rlg_manipulation/pdccompressed/logs_proto/2018-05-09-17-34-32.tar.gz
# ...
# Extracting episode to /content/manip_dataset/data
#
#
# ----- Processing episode 2018-05-09-17-36-30 ---------
# ...
# downloading from url: http://data.csail.mit.edu/rlg_manipulation/pdccompressed/logs_proto/2018-05-09-17-36-30.tar.gz
# ...
# Extracting episode to /content/manip_dataset/data
#
#
# ----- Processing episode 2018-05-09-17-43-26 ---------
# ...
# downloading from url: http://data.csail.mit.edu/rlg_manipulation/pdccompressed/logs_proto/2018-05-09-17-43-26.tar.gz
# ...
# Extracting episode to /content/manip_dataset/data
#
#
# ----- Processing episode 2018-05-09-17-45-21 ---------
# ...

# %%
# !unzip kpam_annotations.zip -d manip_dataset/
# Out:
# Archive:  kpam_annotations.zip
#    creating: manip_dataset/kpam_annotations/
#    creating: manip_dataset/kpam_annotations/keypoints/
#    creating: manip_dataset/kpam_annotations/keypoints/mug_2_keypoint/
#   inflating: manip_dataset/kpam_annotations/keypoints/mug_2_keypoint/scene_2018-05-09-17-59-10_date_2019-02-14-01-55-23.yaml
#   inflating: manip_dataset/kpam_annotations/keypoints/mug_2_keypoint/scene_2018-05-09-17-32-07_date_2019-02-14-01-14-50.yaml
#   inflating: manip_dataset/kpam_annotations/keypoints/mug_2_keypoint/scene_2018-05-15-00-59-42_date_2019-02-14-02-26-32.yaml
#   inflating: manip_dataset/kpam_annotations/keypoints/mug_2_keypoint/scene_2018-05-09-17-53-41_date_2019-02-14-01-30-15.yaml
#   inflating: manip_dataset/kpam_annotations/keypoints/mug_2_keypoint/scene_2018-05-09-17-49-03_date_2019-02-14-01-27-04.yaml
#   inflating: manip_dataset/kpam_annotations/keypoints/mug_2_keypoint/scene_2018-05-14-22-35-08_date_2019-02-14-02-03-45.yaml
# ...

# %%
# !python3 mankey-ros/mankey/dataproc/scripts/pdc/keypoint_mesh2img_all_director.py

# %%
# !python3 /content/mankey-ros/mankey/experiment/heatmap_staged_integral.py
# Out:
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-32-07
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-34-32
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-36-30
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-43-26
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-45-21
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-47-10
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-49-03
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-50-59
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-53-41
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-56-41
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-59-10
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-18-01-12
# Processing:  /content/manip_dataset/logs_proto/2018-05-14-22-31-21
# Processing:  /content/manip_dataset/logs_proto/2018-05-14-22-33-14
# ...

# %%
# !python3 /content/mankey-ros/mankey/experiment/heatmap_staged_integral.py
# Out:
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-32-07
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-34-32
# Processing:  /content/manip_dataset/logs_proto/2018-05-09-17-36-30
# Processing:  /content/manip_dataset/logs_proto/2019-02-15-03-41-40
# Processing:  /content/manip_dataset/logs_proto/2019-02-15-03-11-39
# Processing:  /content/manip_dataset/logs_proto/2019-02-15-02-34-50
# Processing:  /content/manip_dataset/logs_proto/2019-02-21-01-22-32
# Processing:  /content/manip_dataset/logs_proto/2019-02-21-03-14-14
# Processing:  /content/manip_dataset/logs_proto/2019-02-21-03-29-44
# The number of images is 9831
# Entry 1768
# The max depth error (mm) is  92.0
# The max pixel error (pixel in 256x256 image) is  114.20952380952383
# Entry 752
# The max depth error (mm) is  18.0
# The max pixel error (pixel in 256x256 image) is  19.651851851851916
# Entry 6633
# The max depth error (mm) is  264.0
# ...

# %%
# !python3 /content/mankey-ros/mankey/experiment/heatmap_composite.py
# Out:
# /content/mankey-ros/mankey/experiment/heatmap_composite.py:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   network.load_state_dict(torch.load(network_path))
# ...
